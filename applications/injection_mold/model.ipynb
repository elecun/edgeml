# %%
'''
Import dependent packages & setup environments
'''
import pandas as pd
import numpy as np
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model 
from matplotlib import pyplot
from sklearn.datasets import make_regression 
from sklearn.preprocessing import MinMaxScaler 
from sklearn.model_selection import train_test_split 
from sklearn.svm import SVR 
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
import warnings


pd.set_option('display.max.colwidth', 50)
pd.set_option('display.width', 1000)
warnings.filterwarnings(action='ignore')

'''
Load Data 
'''
# Materials to use
materials = ["PC", "PA66", "ABS", "PCSMOG", "TPU"]

# Load raw dataset
raw_dataset = pd.read_excel('../../data/iae/injection_mold_5000_v2.xlsx', header=0, index_col=False)
print("Original Raw Data shape : ", raw_dataset.shape)

raw_dataset = raw_dataset.drop(['id', 'datetime', 'mold_name', 'product_quantity'], axis=1).dropna() #remove 3 columns & drop NA
print("> Raw Dataset shape : ", raw_dataset.shape)

# One-hot Encoding for categorical data
raw_onehot = pd.get_dummies(raw_dataset)   # select onehot encoded featureset from raw data
print("> One-Hot encoded data shape : ", raw_onehot.shape)

# select normal dataset
normal_dataset = raw_onehot.loc[raw_onehot["failure_normal"]==1]
print("> Normal data shape : ", normal_dataset.shape)

normal_target = normal_dataset[["weight"]]
normal_source = normal_dataset.drop('weight', axis=1)
print("> Normal Feature shape : ", normal_source.shape)
print("> Normal Target shape : ", normal_target.shape)

''' 
Auto Encoder for regression
'''
# train autoencoder for regression with no compression in the bottleneck layer
n_inputs = normal_source.shape[1]

X_train, X_test, y_train, y_test = train_test_split(normal_source, np.ravel(normal_target), test_size=0.20, shuffle=True)

# Data Scaler
source_scaler = MinMaxScaler()
source_scaler.fit(normal_source)

X_train_scaled = source_scaler.transform(X_train)
X_test_scaled = source_scaler.transform(X_test)


# define encoder
visible = Input(shape=(n_inputs,))
e = Dense(n_inputs*2)(visible)
e = BatchNormalization()(e)
e = ReLU()(e)

# define bottleneck
n_bottleneck = 3#n_inputs
bottleneck = Dense(n_bottleneck)(e)

# define decoder
d = Dense(n_inputs*2)(bottleneck)
d = BatchNormalization()(d)
d = ReLU()(d)

# output layer
output = Dense(n_inputs, activation='linear')(d)

# define autoencoder model
model = Model(inputs=visible, outputs=output)

# compile autoencoder model
model.compile(optimizer='adam', loss='mse')

# plot the autoencoder
plot_model(model, 'autoencoder.png', show_shapes=True)

# fit the autoencoder model to reconstruct input
history = model.fit(X_train_scaled, X_train_scaled, epochs=200, batch_size=16, verbose=2, validation_data=(X_test_scaled, X_test_scaled))

# plot loss
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# define an encoder model (without the decoder)
encoder = Model(inputs=visible, outputs=bottleneck)
plot_model(encoder, 'encoder.png', show_shapes=True)

# save the encoder to file
#encoder.save('encoder.h5')

# reshape target variables so that we can transform them 
y_train = y_train.reshape((len(y_train), 1)) 
y_test = y_test.reshape((len(y_test), 1))

# target data scaler
target_scaler = MinMaxScaler()
target_scaler.fit(normal_target)
y_train = target_scaler.transform(y_train)
y_test = target_scaler.transform(y_test)


# load the model from file 
#encoder = load_model('encoder.h5') 

# encode the train data 
X_train_encode = encoder.predict(X_train_scaled) 

# encode the test data 
X_test_encode = encoder.predict(X_test_scaled) 

# define model 
model = SVR() 

# fit model on the training dataset 
model.fit(X_train_encode, y_train) 

# make prediction on test set 
yhat = model.predict(X_test_encode) 

# invert transforms so we can calculate errors 
yhat = yhat.reshape((len(yhat), 1)) 
yhat = target_scaler.inverse_transform(yhat) 
y_test = target_scaler.inverse_transform(y_test) 

# calculate error 
score = mean_absolute_error(y_test, yhat)
print("MAE : ", score) 

# percentage error
pscore = mean_absolute_percentage_error(y_test, yhat)
print("MAPE : ", pscore*100)

# r squared
r2 = r2_score(y_test, yhat, multioutput='variance_weighted')
print("R-squared : ", r2)


# pyplot.plot(y_test, 'bo', label="Real")
# pyplot.plot(yhat, 'ro', label="Predicted")
# pyplot.legend()
# pyplot.show()

# pyplot.plot(y_test, yhat, 'bo')
# pyplot.xlabel("test")
# pyplot.ylabel("predicted")
# pyplot.show()
# Out:
# Original Raw Data shape :  (4977, 74)
# > Raw Dataset shape :  (4930, 70)
# > One-Hot encoded data shape :  (4930, 77)
# > Normal data shape :  (1188, 77)
# > Normal Feature shape :  (1188, 76)
# > Normal Target shape :  (1188, 1)
# Epoch 1/200
# 60/60 - 1s - loss: 0.1292 - val_loss: 0.1238 - 594ms/epoch - 10ms/step
# Epoch 2/200
# 60/60 - 0s - loss: 0.0314 - val_loss: 0.1012 - 85ms/epoch - 1ms/step
# Epoch 3/200
# 60/60 - 0s - loss: 0.0231 - val_loss: 0.0786 - 80ms/epoch - 1ms/step
# Epoch 4/200
# 60/60 - 0s - loss: 0.0201 - val_loss: 0.0542 - 79ms/epoch - 1ms/step
# Epoch 5/200
# 60/60 - 0s - loss: 0.0186 - val_loss: 0.0370 - 81ms/epoch - 1ms/step
# Epoch 6/200
# 60/60 - 0s - loss: 0.0156 - val_loss: 0.0210 - 78ms/epoch - 1ms/step
# Epoch 7/200
# 60/60 - 0s - loss: 0.0158 - val_loss: 0.0134 - 78ms/epoch - 1ms/step
# Epoch 8/200
# 60/60 - 0s - loss: 0.0144 - val_loss: 0.0098 - 79ms/epoch - 1ms/step
# Epoch 9/200
# 60/60 - 0s - loss: 0.0132 - val_loss: 0.0081 - 76ms/epoch - 1ms/step
# Epoch 10/200
# 60/60 - 0s - loss: 0.0142 - val_loss: 0.0076 - 77ms/epoch - 1ms/step
# Epoch 11/200
# 60/60 - 0s - loss: 0.0147 - val_loss: 0.0092 - 78ms/epoch - 1ms/step
# Epoch 12/200
# 60/60 - 0s - loss: 0.0127 - val_loss: 0.0092 - 78ms/epoch - 1ms/step
# Epoch 13/200
# 60/60 - 0s - loss: 0.0138 - val_loss: 0.0089 - 76ms/epoch - 1ms/step
# Epoch 14/200
# 60/60 - 0s - loss: 0.0117 - val_loss: 0.0085 - 78ms/epoch - 1ms/step
# Epoch 15/200
# 60/60 - 0s - loss: 0.0122 - val_loss: 0.0077 - 77ms/epoch - 1ms/step
# Epoch 16/200
# 60/60 - 0s - loss: 0.0110 - val_loss: 0.0073 - 76ms/epoch - 1ms/step
# Epoch 17/200
# 60/60 - 0s - loss: 0.0105 - val_loss: 0.0078 - 76ms/epoch - 1ms/step
# Epoch 18/200
# 60/60 - 0s - loss: 0.0107 - val_loss: 0.0075 - 76ms/epoch - 1ms/step
# Epoch 19/200
# 60/60 - 0s - loss: 0.0110 - val_loss: 0.0064 - 76ms/epoch - 1ms/step
# Epoch 20/200
# 60/60 - 0s - loss: 0.0099 - val_loss: 0.0065 - 76ms/epoch - 1ms/step
# Epoch 21/200
# 60/60 - 0s - loss: 0.0106 - val_loss: 0.0085 - 76ms/epoch - 1ms/step
# Epoch 22/200
# 60/60 - 0s - loss: 0.0107 - val_loss: 0.0063 - 76ms/epoch - 1ms/step
# Epoch 23/200
# 60/60 - 0s - loss: 0.0105 - val_loss: 0.0081 - 76ms/epoch - 1ms/step
# Epoch 24/200
# 60/60 - 0s - loss: 0.0112 - val_loss: 0.0061 - 78ms/epoch - 1ms/step
# Epoch 25/200
# 60/60 - 0s - loss: 0.0091 - val_loss: 0.0064 - 77ms/epoch - 1ms/step
# Epoch 26/200
# 60/60 - 0s - loss: 0.0093 - val_loss: 0.0062 - 76ms/epoch - 1ms/step
# Epoch 27/200
# 60/60 - 0s - loss: 0.0096 - val_loss: 0.0057 - 76ms/epoch - 1ms/step
# Epoch 28/200
# 60/60 - 0s - loss: 0.0092 - val_loss: 0.0060 - 77ms/epoch - 1ms/step
# Epoch 29/200
# 60/60 - 0s - loss: 0.0093 - val_loss: 0.0077 - 76ms/epoch - 1ms/step
# Epoch 30/200
# 60/60 - 0s - loss: 0.0106 - val_loss: 0.0087 - 77ms/epoch - 1ms/step
# Epoch 31/200
# 60/60 - 0s - loss: 0.0099 - val_loss: 0.0064 - 76ms/epoch - 1ms/step
# Epoch 32/200
# 60/60 - 0s - loss: 0.0093 - val_loss: 0.0060 - 77ms/epoch - 1ms/step
# Epoch 33/200
# 60/60 - 0s - loss: 0.0089 - val_loss: 0.0056 - 76ms/epoch - 1ms/step
# Epoch 34/200
# 60/60 - 0s - loss: 0.0095 - val_loss: 0.0059 - 79ms/epoch - 1ms/step
# Epoch 35/200
# 60/60 - 0s - loss: 0.0095 - val_loss: 0.0057 - 75ms/epoch - 1ms/step
# Epoch 36/200
# 60/60 - 0s - loss: 0.0085 - val_loss: 0.0057 - 74ms/epoch - 1ms/step
# Epoch 37/200
# 60/60 - 0s - loss: 0.0088 - val_loss: 0.0071 - 90ms/epoch - 1ms/step
# Epoch 38/200
# 60/60 - 0s - loss: 0.0092 - val_loss: 0.0055 - 78ms/epoch - 1ms/step
# Epoch 39/200
# 60/60 - 0s - loss: 0.0088 - val_loss: 0.0050 - 77ms/epoch - 1ms/step
# Epoch 40/200
# 60/60 - 0s - loss: 0.0083 - val_loss: 0.0054 - 76ms/epoch - 1ms/step
# Epoch 41/200
# 60/60 - 0s - loss: 0.0076 - val_loss: 0.0051 - 75ms/epoch - 1ms/step
# Epoch 42/200
# 60/60 - 0s - loss: 0.0079 - val_loss: 0.0054 - 76ms/epoch - 1ms/step
# Epoch 43/200
# 60/60 - 0s - loss: 0.0080 - val_loss: 0.0057 - 77ms/epoch - 1ms/step
# Epoch 44/200
# 60/60 - 0s - loss: 0.0074 - val_loss: 0.0057 - 76ms/epoch - 1ms/step
# Epoch 45/200
# 60/60 - 0s - loss: 0.0077 - val_loss: 0.0056 - 90ms/epoch - 2ms/step
# Epoch 46/200
# 60/60 - 0s - loss: 0.0081 - val_loss: 0.0064 - 77ms/epoch - 1ms/step
# Epoch 47/200
# 60/60 - 0s - loss: 0.0077 - val_loss: 0.0048 - 76ms/epoch - 1ms/step
# Epoch 48/200
# 60/60 - 0s - loss: 0.0076 - val_loss: 0.0046 - 75ms/epoch - 1ms/step
# Epoch 49/200
# 60/60 - 0s - loss: 0.0076 - val_loss: 0.0058 - 76ms/epoch - 1ms/step
# Epoch 50/200
# 60/60 - 0s - loss: 0.0077 - val_loss: 0.0050 - 75ms/epoch - 1ms/step
# Epoch 51/200
# 60/60 - 0s - loss: 0.0073 - val_loss: 0.0048 - 76ms/epoch - 1ms/step
# Epoch 52/200
# 60/60 - 0s - loss: 0.0071 - val_loss: 0.0055 - 76ms/epoch - 1ms/step
# Epoch 53/200
# 60/60 - 0s - loss: 0.0069 - val_loss: 0.0056 - 86ms/epoch - 1ms/step
# Epoch 54/200
# 60/60 - 0s - loss: 0.0071 - val_loss: 0.0053 - 77ms/epoch - 1ms/step
# Epoch 55/200
# 60/60 - 0s - loss: 0.0072 - val_loss: 0.0054 - 75ms/epoch - 1ms/step
# Epoch 56/200
# 60/60 - 0s - loss: 0.0069 - val_loss: 0.0053 - 76ms/epoch - 1ms/step
# Epoch 57/200
# 60/60 - 0s - loss: 0.0066 - val_loss: 0.0048 - 76ms/epoch - 1ms/step
# Epoch 58/200
# 60/60 - 0s - loss: 0.0062 - val_loss: 0.0056 - 76ms/epoch - 1ms/step
# Epoch 59/200
# 60/60 - 0s - loss: 0.0072 - val_loss: 0.0047 - 76ms/epoch - 1ms/step
# Epoch 60/200
# 60/60 - 0s - loss: 0.0067 - val_loss: 0.0044 - 76ms/epoch - 1ms/step
# Epoch 61/200
# 60/60 - 0s - loss: 0.0065 - val_loss: 0.0043 - 75ms/epoch - 1ms/step
# Epoch 62/200
# 60/60 - 0s - loss: 0.0064 - val_loss: 0.0043 - 75ms/epoch - 1ms/step
# Epoch 63/200
# 60/60 - 0s - loss: 0.0065 - val_loss: 0.0052 - 76ms/epoch - 1ms/step
# Epoch 64/200
# 60/60 - 0s - loss: 0.0062 - val_loss: 0.0046 - 77ms/epoch - 1ms/step
# Epoch 65/200
# 60/60 - 0s - loss: 0.0069 - val_loss: 0.0049 - 77ms/epoch - 1ms/step
# Epoch 66/200
# 60/60 - 0s - loss: 0.0071 - val_loss: 0.0049 - 77ms/epoch - 1ms/step
# Epoch 67/200
# 60/60 - 0s - loss: 0.0067 - val_loss: 0.0046 - 76ms/epoch - 1ms/step
# Epoch 68/200
# 60/60 - 0s - loss: 0.0074 - val_loss: 0.0053 - 77ms/epoch - 1ms/step
# Epoch 69/200
# 60/60 - 0s - loss: 0.0061 - val_loss: 0.0041 - 78ms/epoch - 1ms/step
# Epoch 70/200
# 60/60 - 0s - loss: 0.0064 - val_loss: 0.0046 - 76ms/epoch - 1ms/step
# Epoch 71/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0045 - 74ms/epoch - 1ms/step
# Epoch 72/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0042 - 77ms/epoch - 1ms/step
# Epoch 73/200
# 60/60 - 0s - loss: 0.0060 - val_loss: 0.0044 - 75ms/epoch - 1ms/step
# Epoch 74/200
# 60/60 - 0s - loss: 0.0057 - val_loss: 0.0046 - 78ms/epoch - 1ms/step
# Epoch 75/200
# 60/60 - 0s - loss: 0.0053 - val_loss: 0.0039 - 76ms/epoch - 1ms/step
# Epoch 76/200
# 60/60 - 0s - loss: 0.0059 - val_loss: 0.0042 - 76ms/epoch - 1ms/step
# Epoch 77/200
# 60/60 - 0s - loss: 0.0066 - val_loss: 0.0046 - 76ms/epoch - 1ms/step
# Epoch 78/200
# 60/60 - 0s - loss: 0.0059 - val_loss: 0.0047 - 75ms/epoch - 1ms/step
# Epoch 79/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0038 - 75ms/epoch - 1ms/step
# Epoch 80/200
# 60/60 - 0s - loss: 0.0054 - val_loss: 0.0041 - 76ms/epoch - 1ms/step
# Epoch 81/200
# 60/60 - 0s - loss: 0.0059 - val_loss: 0.0040 - 78ms/epoch - 1ms/step
# Epoch 82/200
# 60/60 - 0s - loss: 0.0052 - val_loss: 0.0036 - 76ms/epoch - 1ms/step
# Epoch 83/200
# 60/60 - 0s - loss: 0.0056 - val_loss: 0.0037 - 76ms/epoch - 1ms/step
# Epoch 84/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0037 - 75ms/epoch - 1ms/step
# Epoch 85/200
# 60/60 - 0s - loss: 0.0058 - val_loss: 0.0050 - 76ms/epoch - 1ms/step
# Epoch 86/200
# 60/60 - 0s - loss: 0.0059 - val_loss: 0.0041 - 76ms/epoch - 1ms/step
# Epoch 87/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0041 - 76ms/epoch - 1ms/step
# Epoch 88/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0038 - 77ms/epoch - 1ms/step
# Epoch 89/200
# 60/60 - 0s - loss: 0.0054 - val_loss: 0.0042 - 76ms/epoch - 1ms/step
# Epoch 90/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0037 - 75ms/epoch - 1ms/step
# Epoch 91/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0037 - 76ms/epoch - 1ms/step
# Epoch 92/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0034 - 76ms/epoch - 1ms/step
# Epoch 93/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0038 - 76ms/epoch - 1ms/step
# Epoch 94/200
# 60/60 - 0s - loss: 0.0057 - val_loss: 0.0047 - 76ms/epoch - 1ms/step
# Epoch 95/200
# 60/60 - 0s - loss: 0.0057 - val_loss: 0.0039 - 75ms/epoch - 1ms/step
# Epoch 96/200
# 60/60 - 0s - loss: 0.0052 - val_loss: 0.0047 - 75ms/epoch - 1ms/step
# Epoch 97/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0040 - 77ms/epoch - 1ms/step
# Epoch 98/200
# 60/60 - 0s - loss: 0.0068 - val_loss: 0.0047 - 77ms/epoch - 1ms/step
# Epoch 99/200
# 60/60 - 0s - loss: 0.0065 - val_loss: 0.0040 - 77ms/epoch - 1ms/step
# Epoch 100/200
# 60/60 - 0s - loss: 0.0057 - val_loss: 0.0040 - 77ms/epoch - 1ms/step
# Epoch 101/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0044 - 76ms/epoch - 1ms/step
# Epoch 102/200
# 60/60 - 0s - loss: 0.0053 - val_loss: 0.0035 - 77ms/epoch - 1ms/step
# Epoch 103/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0037 - 76ms/epoch - 1ms/step
# Epoch 104/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0034 - 76ms/epoch - 1ms/step
# Epoch 105/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0038 - 76ms/epoch - 1ms/step
# Epoch 106/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0044 - 78ms/epoch - 1ms/step
# Epoch 107/200
# 60/60 - 0s - loss: 0.0048 - val_loss: 0.0036 - 77ms/epoch - 1ms/step
# Epoch 108/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0037 - 77ms/epoch - 1ms/step
# Epoch 109/200
# 60/60 - 0s - loss: 0.0054 - val_loss: 0.0043 - 79ms/epoch - 1ms/step
# Epoch 110/200
# 60/60 - 0s - loss: 0.0048 - val_loss: 0.0034 - 77ms/epoch - 1ms/step
# Epoch 111/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0036 - 77ms/epoch - 1ms/step
# Epoch 112/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0039 - 78ms/epoch - 1ms/step
# Epoch 113/200
# 60/60 - 0s - loss: 0.0046 - val_loss: 0.0032 - 82ms/epoch - 1ms/step
# Epoch 114/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0035 - 82ms/epoch - 1ms/step
# Epoch 115/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0033 - 77ms/epoch - 1ms/step
# Epoch 116/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0053 - 76ms/epoch - 1ms/step
# Epoch 117/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0034 - 75ms/epoch - 1ms/step
# Epoch 118/200
# 60/60 - 0s - loss: 0.0046 - val_loss: 0.0036 - 78ms/epoch - 1ms/step
# Epoch 119/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0033 - 78ms/epoch - 1ms/step
# Epoch 120/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0034 - 77ms/epoch - 1ms/step
# Epoch 121/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0041 - 77ms/epoch - 1ms/step
# Epoch 122/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0042 - 83ms/epoch - 1ms/step
# Epoch 123/200
# 60/60 - 0s - loss: 0.0048 - val_loss: 0.0033 - 92ms/epoch - 2ms/step
# Epoch 124/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0035 - 87ms/epoch - 1ms/step
# Epoch 125/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0038 - 84ms/epoch - 1ms/step
# Epoch 126/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0039 - 81ms/epoch - 1ms/step
# Epoch 127/200
# 60/60 - 0s - loss: 0.0048 - val_loss: 0.0035 - 80ms/epoch - 1ms/step
# Epoch 128/200
# 60/60 - 0s - loss: 0.0045 - val_loss: 0.0040 - 82ms/epoch - 1ms/step
# Epoch 129/200
# 60/60 - 0s - loss: 0.0048 - val_loss: 0.0042 - 78ms/epoch - 1ms/step
# Epoch 130/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0040 - 77ms/epoch - 1ms/step
# Epoch 131/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0039 - 76ms/epoch - 1ms/step
# Epoch 132/200
# 60/60 - 0s - loss: 0.0045 - val_loss: 0.0039 - 77ms/epoch - 1ms/step
# Epoch 133/200
# 60/60 - 0s - loss: 0.0048 - val_loss: 0.0040 - 75ms/epoch - 1ms/step
# Epoch 134/200
# 60/60 - 0s - loss: 0.0046 - val_loss: 0.0035 - 77ms/epoch - 1ms/step
# Epoch 135/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0048 - 77ms/epoch - 1ms/step
# Epoch 136/200
# 60/60 - 0s - loss: 0.0056 - val_loss: 0.0048 - 76ms/epoch - 1ms/step
# Epoch 137/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0040 - 77ms/epoch - 1ms/step
# Epoch 138/200
# 60/60 - 0s - loss: 0.0054 - val_loss: 0.0036 - 76ms/epoch - 1ms/step
# Epoch 139/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0035 - 75ms/epoch - 1ms/step
# Epoch 140/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0039 - 76ms/epoch - 1ms/step
# Epoch 141/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0042 - 76ms/epoch - 1ms/step
# Epoch 142/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0033 - 76ms/epoch - 1ms/step
# Epoch 143/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0033 - 77ms/epoch - 1ms/step
# Epoch 144/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0038 - 76ms/epoch - 1ms/step
# Epoch 145/200
# 60/60 - 0s - loss: 0.0045 - val_loss: 0.0042 - 76ms/epoch - 1ms/step
# Epoch 146/200
# 60/60 - 0s - loss: 0.0046 - val_loss: 0.0031 - 77ms/epoch - 1ms/step
# Epoch 147/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0032 - 77ms/epoch - 1ms/step
# Epoch 148/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0041 - 77ms/epoch - 1ms/step
# Epoch 149/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0032 - 76ms/epoch - 1ms/step
# Epoch 150/200
# 60/60 - 0s - loss: 0.0050 - val_loss: 0.0034 - 78ms/epoch - 1ms/step
# Epoch 151/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0031 - 76ms/epoch - 1ms/step
# Epoch 152/200
# 60/60 - 0s - loss: 0.0051 - val_loss: 0.0034 - 77ms/epoch - 1ms/step
# Epoch 153/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0031 - 76ms/epoch - 1ms/step
# Epoch 154/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0034 - 75ms/epoch - 1ms/step
# Epoch 155/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0032 - 76ms/epoch - 1ms/step
# Epoch 156/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0033 - 76ms/epoch - 1ms/step
# Epoch 157/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0032 - 79ms/epoch - 1ms/step
# Epoch 158/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0040 - 82ms/epoch - 1ms/step
# Epoch 159/200
# 60/60 - 0s - loss: 0.0046 - val_loss: 0.0032 - 86ms/epoch - 1ms/step
# Epoch 160/200
# 60/60 - 0s - loss: 0.0046 - val_loss: 0.0034 - 87ms/epoch - 1ms/step
# Epoch 161/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0033 - 87ms/epoch - 1ms/step
# Epoch 162/200
# 60/60 - 0s - loss: 0.0043 - val_loss: 0.0032 - 84ms/epoch - 1ms/step
# Epoch 163/200
# 60/60 - 0s - loss: 0.0043 - val_loss: 0.0036 - 79ms/epoch - 1ms/step
# Epoch 164/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0031 - 81ms/epoch - 1ms/step
# Epoch 165/200
# 60/60 - 0s - loss: 0.0040 - val_loss: 0.0030 - 79ms/epoch - 1ms/step
# Epoch 166/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0029 - 79ms/epoch - 1ms/step
# Epoch 167/200
# 60/60 - 0s - loss: 0.0043 - val_loss: 0.0036 - 81ms/epoch - 1ms/step
# Epoch 168/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0038 - 81ms/epoch - 1ms/step
# Epoch 169/200
# 60/60 - 0s - loss: 0.0040 - val_loss: 0.0031 - 81ms/epoch - 1ms/step
# Epoch 170/200
# 60/60 - 0s - loss: 0.0055 - val_loss: 0.0053 - 76ms/epoch - 1ms/step
# Epoch 171/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0036 - 76ms/epoch - 1ms/step
# Epoch 172/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0033 - 77ms/epoch - 1ms/step
# Epoch 173/200
# 60/60 - 0s - loss: 0.0044 - val_loss: 0.0030 - 76ms/epoch - 1ms/step
# Epoch 174/200
# 60/60 - 0s - loss: 0.0039 - val_loss: 0.0029 - 75ms/epoch - 1ms/step
# Epoch 175/200
# 60/60 - 0s - loss: 0.0040 - val_loss: 0.0033 - 77ms/epoch - 1ms/step
# Epoch 176/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0034 - 76ms/epoch - 1ms/step
# Epoch 177/200
# 60/60 - 0s - loss: 0.0039 - val_loss: 0.0038 - 77ms/epoch - 1ms/step
# Epoch 178/200
# 60/60 - 0s - loss: 0.0043 - val_loss: 0.0031 - 75ms/epoch - 1ms/step
# Epoch 179/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0031 - 77ms/epoch - 1ms/step
# Epoch 180/200
# 60/60 - 0s - loss: 0.0043 - val_loss: 0.0034 - 80ms/epoch - 1ms/step
# Epoch 181/200
# 60/60 - 0s - loss: 0.0049 - val_loss: 0.0034 - 77ms/epoch - 1ms/step
# Epoch 182/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0029 - 76ms/epoch - 1ms/step
# Epoch 183/200
# 60/60 - 0s - loss: 0.0038 - val_loss: 0.0030 - 80ms/epoch - 1ms/step
# Epoch 184/200
# 60/60 - 0s - loss: 0.0038 - val_loss: 0.0033 - 80ms/epoch - 1ms/step
# Epoch 185/200
# 60/60 - 0s - loss: 0.0037 - val_loss: 0.0028 - 77ms/epoch - 1ms/step
# Epoch 186/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0036 - 75ms/epoch - 1ms/step
# Epoch 187/200
# 60/60 - 0s - loss: 0.0047 - val_loss: 0.0038 - 75ms/epoch - 1ms/step
# Epoch 188/200
# 60/60 - 0s - loss: 0.0045 - val_loss: 0.0035 - 76ms/epoch - 1ms/step
# Epoch 189/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0030 - 76ms/epoch - 1ms/step
# Epoch 190/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0031 - 81ms/epoch - 1ms/step
# Epoch 191/200
# 60/60 - 0s - loss: 0.0041 - val_loss: 0.0035 - 75ms/epoch - 1ms/step
# Epoch 192/200
# 60/60 - 0s - loss: 0.0052 - val_loss: 0.0039 - 76ms/epoch - 1ms/step
# Epoch 193/200
# 60/60 - 0s - loss: 0.0040 - val_loss: 0.0033 - 75ms/epoch - 1ms/step
# Epoch 194/200
# 60/60 - 0s - loss: 0.0040 - val_loss: 0.0031 - 75ms/epoch - 1ms/step
# Epoch 195/200
# 60/60 - 0s - loss: 0.0039 - val_loss: 0.0030 - 76ms/epoch - 1ms/step
# Epoch 196/200
# 60/60 - 0s - loss: 0.0039 - val_loss: 0.0029 - 78ms/epoch - 1ms/step
# Epoch 197/200
# 60/60 - 0s - loss: 0.0037 - val_loss: 0.0031 - 78ms/epoch - 1ms/step
# Epoch 198/200
# 60/60 - 0s - loss: 0.0038 - val_loss: 0.0030 - 79ms/epoch - 1ms/step
# Epoch 199/200
# 60/60 - 0s - loss: 0.0045 - val_loss: 0.0032 - 75ms/epoch - 1ms/step
# Epoch 200/200
# 60/60 - 0s - loss: 0.0042 - val_loss: 0.0032 - 75ms/epoch - 1ms/step
# 30/30 [==============================] - 0s 707us/step
# 8/8 [==============================] - 0s 658us/step
# MAE :  2.35705228809649
# MAPE :  1.2008474174420196
# R-squared :  0.9038874129291131
